# %% [markdown]
# # metadata

# %%
import pandas as pd
import numpy as np

# %%
participants = pd.read_csv('./participants.csv')

# %%
df = pd.DataFrame(participants)

# %%
df.columns
# Out:
# Index(['participant_id', ' age', ' gender', ' hand', ' MMSE', ' NAART',
#        ' disease_duration', ' rl_deficits', ' notes'],
#       dtype='object')

# %%
ages = df[' age'].to_list()

# %%
np.mean(ages)
# Out:
# 63.38709677419355

# %%
import matplotlib.pyplot as plt

vals = [980, 20]
labels = ["Здоровые и др", "БП"]
explode = [0, 0.1]
colors = ['#5e86b8', '#a1c2df']
fig, ax = plt.subplots()

ax.pie(vals, labels=labels, autopct='%1.1f%%', colors=colors, shadow=True, explode=explode, wedgeprops={'lw':1, 'ls':'-','edgecolor':"w"}, rotatelabels=False)
ax.axis("equal")

plt.show()
